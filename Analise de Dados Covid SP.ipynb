# %%
import pandas as pd
low_memory=False
import matplotlib.pyplot as plt
# %matplotlib inline
pd.options.display.max_columns = 80
pd.options.display.max_rows = 90

# %%
filename = r'C:\Users\ITX Gamer\Desktop\HIST_PAINEL_COVIDBR_01jul2020.xlsx'
df = pd.read_excel(filename)

# %%
df.columns
# Out:
# Index(['regiao', 'estado', 'municipio', 'coduf', 'codmun', 'codRegiaoSaude',
#        'nomeRegiaoSaude', 'data', 'semana', 'populacao', 'CasosAcumulados',
#        'CasosNovos', 'ObitosAcumulados', 'ObitosNovos', 'Recuperadosnovos',
#        'emAcompanhamentoNovos', 'interior/metropolitana'],
#       dtype='object')

# %%
df.rename(columns={'semanaEpi':'semana','casosAcumulado':'CasosAcumulados','casosNovos':'CasosNovos','obitosAcumulado':'ObitosAcumulados','obitosNovos':'ObitosNovos'}, inplace=True)

# %%
sp = df.query('estado == "SP"')
sp.groupby('municipio')['CasosAcumulados'].max().sort_values().tail(10).plot(kind='pie', figsize=(8,8))

# %%
sp.groupby('semana')['CasosAcumulados'].max().sort_values().tail(31).plot(kind='bar', figsize=(10,5))

# %%
sp.groupby('semana')['CasosNovos'].max().tail(10).plot(kind='area')

# %%
sp.isnull().sum()
# Out:
# regiao                        0
# estado                        0
# municipio                   225
# coduf                         0
# codmun                      128
# codRegiaoSaude              225
# nomeRegiaoSaude             225
# data                          0
# semana                        0
# populacao                    97
# CasosAcumulados               0
# CasosNovos                    0
# ObitosAcumulados              0
# ObitosNovos                   0
# Recuperadosnovos          60947
# emAcompanhamentoNovos     60947
# interior/metropolitana      225
# dtype: int64

# %%
sp.groupby('semana')['ObitosAcumulados'].max().sort_values().tail(31).plot(kind='bar', figsize=(10,5))

# %%
sp.groupby ('semana')['ObitosNovos'].max().tail(10).plot(kind='barh')
